# %%
import networkx as nx
import matplotlib.pyplot as plt
from nanonets import NanoparticleTopology

# %% [markdown]
# # Lattice Networks

# %%
# Parameter and Inti
N_x, N_y        = 5,3
electrode_pos   = [[0,0],[2,0],[0,2],[2,2]]
lattice_net     = NanoparticleTopology()

# Build Network and attach Electrodes
lattice_net.lattice_network(N_x, N_y)
lattice_net.add_electrodes_to_lattice_net(electrode_pos)

# Extract Graph & Positions
G   = lattice_net.get_graph()
pos = lattice_net.get_positions()

print(lattice_net)
fig, ax = plt.subplots(dpi=150)
nx.draw_networkx(G=G, pos=pos, ax=ax)
# Out:
# Topology Class with 15 particles, 5 junctions.
# Network Topology:
# [[   1    1    5 -100 -100 -100]
#  [-100    0    2    6 -100 -100]
#  [   2    1    3    7 -100 -100]
#  [-100    2    4    8 -100 -100]
#  [-100    3    9 -100 -100 -100]
#  [-100    0    6   10 -100 -100]
#  [-100    1    5    7   11 -100]
#  [-100    2    6    8   12 -100]
#  [-100    3    7    9   13 -100]
#  [-100    4    8   14 -100 -100]
#  [   3    5   11 -100 -100 -100]
#  [-100    6   10   12 -100 -100]
#  [   4    7   11   13 -100 -100]
#  [-100    8   12   14 -100 -100]
#  [-100    9   13 -100 -100 -100]]

# %% [markdown]
# # Random Networks

# %%
# Parameter and Inti
N_particles     = 20
electrode_pos   = [[-1,-1],[-1,1],[1,-1],[1,1]]
rng_net         = NanoparticleTopology()

# Build Network and attach Electrodes
rng_net.random_network(N_particles)
rng_net.add_electrodes_to_random_net(electrode_pos)

# Extract Graph & Positions
G   = rng_net.get_graph()
pos = rng_net.get_positions()

print(rng_net)
fig, ax = plt.subplots(dpi=150)
nx.draw_networkx(G=G, pos=pos, ax=ax)
# Out:
# Topology Class with 20 particles, 8 junctions.
# Network Topology:
# [[-100    8   10   13   19    9 -100 -100 -100]
#  [-100    3   12    4    7   10 -100 -100 -100]
#  [-100    5   14    7   12   18 -100 -100 -100]
#  [-100    4   10   13    1 -100 -100 -100 -100]
#  [   2    3   12   16    1 -100 -100 -100 -100]
#  [-100   16    2   12   18 -100 -100 -100 -100]
#  [   3   15   11    8   17 -100 -100 -100 -100]
#  [-100   10    2    9   12   15    1   14 -100]
#  [-100    9    0    6   11   19 -100 -100 -100]
#  [-100    8   11   10    7    0   15 -100 -100]
#  [-100    3    7    9    0   13    1 -100 -100]
#  [-100    9    6    8   15 -100 -100 -100 -100]
#  [-100   16    4    1    5    7    2 -100 -100]
#  [-100    3    0   19   10 -100 -100 -100 -100]
#  [-100    2   18   15   17    7 -100 -100 -100]
#  [-100    6   17   14    7    9   11 -100 -100]
#  [-100   12    5    4 -100 -100 -100 -100 -100]
#  [-100   18   15    6   14 -100 -100 -100 -100]
#  [   4   17   14    5    2 -100 -100 -100 -100]
#  [   1    0   13    8 -100 -100 -100 -100 -100]]

# %% [markdown]
# # Add a NP to the Output Electrode

# %%
# Parameter and Inti
N_x, N_y        = 5,3
electrode_pos   = [[0,0],[2,0],[0,2],[2,2]]
lattice_net     = NanoparticleTopology()

# Build Network and attach Electrodes
lattice_net.lattice_network(N_x, N_y)
lattice_net.add_electrodes_to_lattice_net(electrode_pos)
lattice_net.add_np_to_output()

# Extract Graph & Positions
G   = lattice_net.get_graph()
pos = lattice_net.get_positions()

print(lattice_net)
fig, ax = plt.subplots(dpi=150)
nx.draw_networkx(G=G, pos=pos, ax=ax)
# Out:
# Topology Class with 16 particles, 5 junctions.
# Network Topology:
# [[   1    1    5 -100 -100 -100]
#  [-100    0    2    6 -100 -100]
#  [   2    1    3    7 -100 -100]
#  [-100    2    4    8 -100 -100]
#  [-100    3    9 -100 -100 -100]
#  [-100    0    6   10 -100 -100]
#  [-100    1    5    7   11 -100]
#  [-100    2    6    8   12 -100]
#  [-100    3    7    9   13 -100]
#  [-100    4    8   14 -100 -100]
#  [   3    5   11 -100 -100 -100]
#  [-100    6   10   12 -100 -100]
#  [-100    7   11   13   15 -100]
#  [-100    8   12   14 -100 -100]
#  [-100    9   13 -100 -100 -100]
#  [   4   12 -100 -100 -100 -100]]

# %%
# Parameter and Inti
N_particles     = 20
electrode_pos   = [[-1,-1],[-1,1],[1,-1],[1,1]]
rng_net         = NanoparticleTopology()

# Build Network and attach Electrodes
rng_net.random_network(N_particles)
rng_net.add_electrodes_to_random_net(electrode_pos)
rng_net.add_np_to_output()

# Extract Graph & Positions
G   = rng_net.get_graph()
pos = rng_net.get_positions()

print(rng_net)
fig, ax = plt.subplots(dpi=150)
nx.draw_networkx(G=G, pos=pos, ax=ax)
# Out:
# Topology Class with 21 particles, 10 junctions.
# Network Topology:
# [[-100   16    6   15   18 -100 -100 -100 -100 -100 -100]
#  [-100    9    3   11   17   13   20 -100 -100 -100 -100]
#  [-100   11   14    4   19   12 -100 -100 -100 -100 -100]
#  [-100   16   13    1    9   18   15    5    8   14 -100]
#  [-100   12    2    7   19 -100 -100 -100 -100 -100 -100]
#  [-100   10    9   15    3 -100 -100 -100 -100 -100 -100]
#  [   1   12   18    8    7    0 -100 -100 -100 -100 -100]
#  [-100    6   12    4 -100 -100 -100 -100 -100 -100 -100]
#  [-100   12   18    6   14    3 -100 -100 -100 -100 -100]
#  [-100   17    1    3    5   10 -100 -100 -100 -100 -100]
#  [-100    5   15    9 -100 -100 -100 -100 -100 -100 -100]
#  [-100   14    2   17    1   13   19 -100 -100 -100 -100]
#  [-100    6    4    8    7   14    2 -100 -100 -100 -100]
#  [-100    3   14   11    1 -100 -100 -100 -100 -100 -100]
#  [-100   11    2   13    8   12    3 -100 -100 -100 -100]
#  [   3   10    3    5   16    0 -100 -100 -100 -100 -100]
#  [-100    3    0   15   18 -100 -100 -100 -100 -100 -100]
#  [-100    9   11    1   19 -100 -100 -100 -100 -100 -100]
#  [-100    6    8    3   16    0 -100 -100 -100 -100 -100]
#  [   2   11    2    4   17 -100 -100 -100 -100 -100 -100]
#  [   4    1 -100 -100 -100 -100 -100 -100 -100 -100 -100]]
