# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scienceplots

from nanonets import Simulation

plt.style.use(["science","bright","grid"])
# %matplotlib inline

N_PARTICLES     = 9
N_ELECTRODES    = 8
# PATH            = "/home/j/j_mens07/bagheera/data/1_funding_period/iv_curves/control_impact/"
PATH            = "/home/jonasmensing/bagheera/data/1_funding_period/iv_curves/control_impact/"
CONTROL_POS     = [0,2,5]

# %% [markdown]
# # Unscaled

# %% [markdown]
# ### $V = 0.01$

# %%
data    = {}
V_INPUT = 0.01
for pos in CONTROL_POS:
    df = pd.read_csv(f"{PATH}Nx={N_PARTICLES}_Ny={N_PARTICLES}_Ne={N_ELECTRODES}_{V_INPUT}_{pos}.csv")
    df = df.sort_values(by=f'E{pos}').reset_index(drop=True)
    data[pos] = df

# %%
fig = plt.figure(dpi=200)
ax  = fig.add_subplot()
for pos in CONTROL_POS:
    ax.plot(data[pos].loc[:,f'E{pos}'].values*1000, data[pos].loc[:,'Observable'].values*1e-6, label=f'$i = {pos}$')
    ax.fill_between(data[pos].loc[:,f'E{pos}'].values*1000,
                    (data[pos].loc[:,'Observable'].values - data[pos].loc[:,'Error'].values)*1e-6,
                    (data[pos].loc[:,'Observable'].values + data[pos].loc[:,'Error'].values)*1e-6,
                    color='black', alpha=0.5)
ax.set_xlabel("$U_i$ [mV]")
ax.set_ylabel("$I$ [pA]")
ax.legend(fontsize='small')
ax.set_xlim(-100,100)
ax.set_ylim(-80,80)
ax.set_title(f"$U_1 = {V_INPUT}$ [V]")
# Out:
# Text(0.5, 1.0, '$U_1 = 0.01$ [V]')

# %% [markdown]
# ### $V = 0.02$

# %%
data    = {}
V_INPUT = 0.02
for pos in CONTROL_POS:
    df = pd.read_csv(f"{PATH}Nx={N_PARTICLES}_Ny={N_PARTICLES}_Ne={N_ELECTRODES}_{V_INPUT}_{pos}.csv")
    df = df.sort_values(by=f'E{pos}').reset_index(drop=True)
    data[pos] = df

# %%
fig = plt.figure(dpi=200)
ax  = fig.add_subplot()
for pos in CONTROL_POS:
    ax.plot(data[pos].loc[:,f'E{pos}'].values*1000, data[pos].loc[:,'Observable'].values*1e-6, label=f'$i = {pos}$')
    ax.fill_between(data[pos].loc[:,f'E{pos}'].values*1000,
                    (data[pos].loc[:,'Observable'].values - data[pos].loc[:,'Error'].values)*1e-6,
                    (data[pos].loc[:,'Observable'].values + data[pos].loc[:,'Error'].values)*1e-6,
                    color='black', alpha=0.5)
ax.set_xlabel("$U_i$ [mV]")
ax.set_ylabel("$I$ [pA]")
ax.legend(fontsize='small')
ax.set_xlim(-100,100)
ax.set_ylim(-80,80)
ax.set_title(f"$U_1 = {V_INPUT}$ [V]")
# Out:
# Text(0.5, 1.0, '$U_1 = 0.02$ [V]')

# %% [markdown]
# ### $V = 0.03$

# %%
data    = {}
V_INPUT = 0.03
for pos in CONTROL_POS:
    df = pd.read_csv(f"{PATH}Nx={N_PARTICLES}_Ny={N_PARTICLES}_Ne={N_ELECTRODES}_{V_INPUT}_{pos}.csv")
    df = df.sort_values(by=f'E{pos}').reset_index(drop=True)
    data[pos] = df

# %%
fig = plt.figure(dpi=200)
ax  = fig.add_subplot()
for pos in CONTROL_POS:
    ax.plot(data[pos].loc[:,f'E{pos}'].values*1000, data[pos].loc[:,'Observable'].values*1e-6, label=f'$i = {pos}$')
    ax.fill_between(data[pos].loc[:,f'E{pos}'].values*1000,
                    (data[pos].loc[:,'Observable'].values - data[pos].loc[:,'Error'].values)*1e-6,
                    (data[pos].loc[:,'Observable'].values + data[pos].loc[:,'Error'].values)*1e-6,
                    color='black', alpha=0.5)
ax.set_xlabel("$U_i$ [mV]")
ax.set_ylabel("$I$ [pA]")
ax.legend(fontsize='small')
ax.set_xlim(-100,100)
ax.set_ylim(-80,80)
ax.set_title(f"$U_1 = {V_INPUT}$ [V]")
# Out:
# Text(0.5, 1.0, '$U_1 = 0.03$ [V]')

# %%
I_out = [data[pos]['Observable'].values for pos in CONTROL_POS]
np.save("vals.npy",np.array(I_out).T)

# %% [markdown]
# ### $V = 0.04$

# %%
data    = {}
V_INPUT = 0.04
for pos in CONTROL_POS:
    df = pd.read_csv(f"{PATH}Nx={N_PARTICLES}_Ny={N_PARTICLES}_Ne={N_ELECTRODES}_{V_INPUT}_{pos}.csv")
    df = df.sort_values(by=f'E{pos}').reset_index(drop=True)
    data[pos] = df

# %%
fig = plt.figure(dpi=200)
ax  = fig.add_subplot()
for pos in CONTROL_POS:
    ax.plot(data[pos].loc[:,f'E{pos}'].values*1000, data[pos].loc[:,'Observable'].values*1e-6, label=f'$i = {pos}$')
    ax.fill_between(data[pos].loc[:,f'E{pos}'].values*1000,
                    (data[pos].loc[:,'Observable'].values - data[pos].loc[:,'Error'].values)*1e-6,
                    (data[pos].loc[:,'Observable'].values + data[pos].loc[:,'Error'].values)*1e-6,
                    color='black', alpha=0.5)
ax.set_xlabel("$U_i$ [mV]")
ax.set_ylabel("$I$ [pA]")
ax.legend(fontsize='small')
ax.set_xlim(-100,100)
ax.set_ylim(-80,80)
ax.set_title(f"$U_1 = {V_INPUT}$ [V]")
# Out:
# Text(0.5, 1.0, '$U_1 = 0.04$ [V]')

# %% [markdown]
# ### $V = 0.05$

# %%
data    = {}
V_INPUT = 0.05
for pos in CONTROL_POS:
    df = pd.read_csv(f"{PATH}Nx={N_PARTICLES}_Ny={N_PARTICLES}_Ne={N_ELECTRODES}_{pos}.csv")
    df = df.sort_values(by=f'E{pos}').reset_index(drop=True)
    data[pos] = df

# %%
fig = plt.figure(dpi=200)
ax  = fig.add_subplot()
for pos in CONTROL_POS:
    ax.plot(data[pos].loc[:,f'E{pos}'].values*1000, data[pos].loc[:,'Observable'].values*1e-6, label=f'$i = {pos}$')
    ax.fill_between(data[pos].loc[:,f'E{pos}'].values*1000,
                    (data[pos].loc[:,'Observable'].values - data[pos].loc[:,'Error'].values)*1e-6,
                    (data[pos].loc[:,'Observable'].values + data[pos].loc[:,'Error'].values)*1e-6,
                    color='black', alpha=0.5)
ax.set_xlabel("$U_i$ [mV]")
ax.set_ylabel("$I$ [pA]")
ax.legend(fontsize='small')
ax.set_xlim(-100,100)
ax.set_ylim(-80,80)
ax.set_title(f"$U_1 = {V_INPUT}$ [V]")
# Out:
# Text(0.5, 1.0, '$U_1 = 0.05$ [V]')

# %% [markdown]
# # Scaled

# %% [markdown]
# ### $V_C = 0.03$

# %%
data    = {}
V_RANGE = 0.03
for pos in CONTROL_POS:
    df = pd.read_csv(f"{PATH}Nx={N_PARTICLES}_Ny={N_PARTICLES}_Ne={N_ELECTRODES}_{V_RANGE}_{pos}_scaled.csv")
    df = df.sort_values(by=f'E{pos}').reset_index(drop=True)
    df[f'E{pos}'] = 2*(df[f'E{pos}'] - df[f'E{pos}'].min()) / (df[f'E{pos}'].max() - df[f'E{pos}'].min()) - 1
    data[pos] = df

# %%
fig = plt.figure(dpi=200)
ax  = fig.add_subplot()
for pos in CONTROL_POS:
    ax.plot(data[pos].loc[:,f'E{pos}'].values, data[pos].loc[:,'Observable'].values*1e-6, label=f'$i = {pos}$')
    ax.fill_between(data[pos].loc[:,f'E{pos}'].values,
                    (data[pos].loc[:,'Observable'].values - data[pos].loc[:,'Error'].values)*1e-6,
                    (data[pos].loc[:,'Observable'].values + data[pos].loc[:,'Error'].values)*1e-6,
                    color='black', alpha=0.5)
ax.set_xlabel("$U_i$")
ax.set_ylabel("$I$ [pA]")
ax.legend(fontsize='small')
# ax.set_xlim(-100,100)
# ax.set_ylim(-80,80)
ax.set_title(f"$U_1 = {0.03}$ V, $U_C = {V_RANGE}$ V")
# Out:
# Text(0.5, 1.0, '$U_1 = 0.03$ V, $U_C = 0.03$ V')

# %% [markdown]
# ### $V_C = 0.06$

# %%
data    = {}
V_RANGE = 0.06
for pos in CONTROL_POS:
    df = pd.read_csv(f"{PATH}Nx={N_PARTICLES}_Ny={N_PARTICLES}_Ne={N_ELECTRODES}_{V_RANGE}_{pos}_scaled.csv")
    df = df.sort_values(by=f'E{pos}').reset_index(drop=True)
    df[f'E{pos}'] = 2*(df[f'E{pos}'] - df[f'E{pos}'].min()) / (df[f'E{pos}'].max() - df[f'E{pos}'].min()) - 1
    data[pos] = df

# %%
fig = plt.figure(dpi=200)
ax  = fig.add_subplot()
for pos in CONTROL_POS:
    ax.plot(data[pos].loc[:,f'E{pos}'].values, data[pos].loc[:,'Observable'].values*1e-6, label=f'$i = {pos}$')
    ax.fill_between(data[pos].loc[:,f'E{pos}'].values,
                    (data[pos].loc[:,'Observable'].values - data[pos].loc[:,'Error'].values)*1e-6,
                    (data[pos].loc[:,'Observable'].values + data[pos].loc[:,'Error'].values)*1e-6,
                    color='black', alpha=0.5)
ax.set_xlabel("$U_i$")
ax.set_ylabel("$I$ [pA]")
ax.legend(fontsize='small')
# ax.set_xlim(-100,100)
# ax.set_ylim(-80,80)
ax.set_title(f"$U_1 = {0.03}$ V, $U_C = {V_RANGE}$ V")
# Out:
# Text(0.5, 1.0, '$U_1 = 0.03$ V, $U_C = 0.06$ V')

# %% [markdown]
# ### $V_C = 0.09$

# %%
data    = {}
V_RANGE = 0.09
for pos in CONTROL_POS:
    df = pd.read_csv(f"{PATH}Nx={N_PARTICLES}_Ny={N_PARTICLES}_Ne={N_ELECTRODES}_{V_RANGE}_{pos}_scaled.csv")
    df = df.sort_values(by=f'E{pos}').reset_index(drop=True)
    df[f'E{pos}'] = 2*(df[f'E{pos}'] - df[f'E{pos}'].min()) / (df[f'E{pos}'].max() - df[f'E{pos}'].min()) - 1
    data[pos] = df

# %%
fig = plt.figure(dpi=200)
ax  = fig.add_subplot()
for pos in CONTROL_POS:
    ax.plot(data[pos].loc[:,f'E{pos}'].values, data[pos].loc[:,'Observable'].values*1e-6, label=f'$i = {pos}$')
    ax.fill_between(data[pos].loc[:,f'E{pos}'].values,
                    (data[pos].loc[:,'Observable'].values - data[pos].loc[:,'Error'].values)*1e-6,
                    (data[pos].loc[:,'Observable'].values + data[pos].loc[:,'Error'].values)*1e-6,
                    color='black', alpha=0.5)
ax.set_xlabel("$U_i$")
ax.set_ylabel("$I$ [pA]")
ax.legend(fontsize='small')
# ax.set_xlim(-100,100)
# ax.set_ylim(-80,80)
ax.set_title(f"$U_1 = {0.03}$ V, $U_C = {V_RANGE}$ V")
# Out:
# Text(0.5, 1.0, '$U_1 = 0.03$ V, $U_C = 0.09$ V')

# %% [markdown]
# - Input States: $(0,0)$, $(30,0)$, $(0,30)$, $(30,30)$
# - Voltage Range: $[90,90]$
