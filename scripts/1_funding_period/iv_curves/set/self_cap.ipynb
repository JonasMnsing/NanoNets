# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scienceplots

from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize

plt.style.use(["science","bright","grid"])

PLOT_NORM   = Normalize(vmin=0, vmax=10)
CMAP        = plt.get_cmap('cividis')
PATH        = "/home/j/j_mens07/phd/data/1_funding_period/iv_curves/iv_curves_self_cap/"

# %%
marker  = ['o','s','X','<','>','^','v']
fig, ax = plt.subplots(dpi=300)
w, h    = fig.get_size_inches()
scale   = 0.75
fig.set_size_inches(w * scale, h * scale)

# Cg = 0
df      = pd.read_csv(f"{PATH}set_zero.csv").sort_values(by='E0').reset_index(drop=True)
_       = ax.errorbar(df['E0'].values*1000, df['Observable'].values*1e-9, df['Error']*1e-9, color=CMAP(PLOT_NORM(0)))

# Cg = 1
df      = pd.read_csv(f"{PATH}set_one.csv").sort_values(by='E0').reset_index(drop=True)
_       = ax.errorbar(df['E0'].values*1000, df['Observable'].values*1e-9, df['Error']*1e-9, color=CMAP(PLOT_NORM(1)))

# Cg = 2
df      = pd.read_csv(f"{PATH}set_two.csv").sort_values(by='E0').reset_index(drop=True)
_       = ax.errorbar(df['E0'].values*1000, df['Observable'].values*1e-9, df['Error']*1e-9, color=CMAP(PLOT_NORM(2)))

# Cg = 3
df      = pd.read_csv(f"{PATH}set_three.csv").sort_values(by='E0').reset_index(drop=True)
_       = ax.errorbar(df['E0'].values*1000, df['Observable'].values*1e-9, df['Error']*1e-9, color=CMAP(PLOT_NORM(3)))

# Cg = 4
df      = pd.read_csv(f"{PATH}set_four.csv").sort_values(by='E0').reset_index(drop=True)
_       = ax.errorbar(df['E0'].values*1000, df['Observable'].values*1e-9, df['Error']*1e-9, color=CMAP(PLOT_NORM(4)))

# Cg = 5
df      = pd.read_csv(f"{PATH}set_five.csv").sort_values(by='E0').reset_index(drop=True)
_       = ax.errorbar(df['E0'].values*1000, df['Observable'].values*1e-9, df['Error']*1e-9, color=CMAP(PLOT_NORM(5)))

# Cg = 6
df      = pd.read_csv(f"{PATH}set_six.csv").sort_values(by='E0').reset_index(drop=True)
_       = ax.errorbar(df['E0'].values*1000, df['Observable'].values*1e-9, df['Error']*1e-9, color=CMAP(PLOT_NORM(6)))

# Cg = 7
df      = pd.read_csv(f"{PATH}set_seven.csv").sort_values(by='E0').reset_index(drop=True)
_       = ax.errorbar(df['E0'].values*1000, df['Observable'].values*1e-9, df['Error']*1e-9, color=CMAP(PLOT_NORM(7)))

# Cg = 8
df      = pd.read_csv(f"{PATH}set_eight.csv").sort_values(by='E0').reset_index(drop=True)
_       = ax.errorbar(df['E0'].values*1000, df['Observable'].values*1e-9, df['Error']*1e-9, color=CMAP(PLOT_NORM(8)))

# Cg = 9
df      = pd.read_csv(f"{PATH}set_nine.csv").sort_values(by='E0').reset_index(drop=True)
_       = ax.errorbar(df['E0'].values*1000, df['Observable'].values*1e-9, df['Error']*1e-9, color=CMAP(PLOT_NORM(9)))

# Cg = 10
df      = pd.read_csv(f"{PATH}set_ten.csv").sort_values(by='E0').reset_index(drop=True)
_       = ax.errorbar(df['E0'].values*1000, df['Observable'].values*1e-9, df['Error']*1e-9, color=CMAP(PLOT_NORM(10)))

_       = ax.set_xlabel("$U~[\\mathrm{mV}]$")
_       = ax.set_ylabel("$I~[\\mathrm{nA}]$")
# _       = ax.legend(fontsize='x-small', ncol=1, loc='upper left')
_       = ax.set_ylim(-1,1)
_       = ax.set_xlim(-80,80)

sm  = ScalarMappable(cmap=CMAP, norm=PLOT_NORM)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label("$C_g~[\mathrm{aF}]$")
