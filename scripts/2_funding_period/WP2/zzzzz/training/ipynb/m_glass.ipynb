# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data    = np.loadtxt("../m_data.csv", delimiter=',')
x       = data[:,0]
x       = 0.05*(x - np.mean(x)) / np.std(x)
y       = data[:,1]
y       = 0.05*(y - np.mean(y)) / np.std(y)

# %%
plt.plot(x)

# %%
da
