# %%
import networkx as nx
import matplotlib.pyplot as plt
import sys
sys.path.append("../")
import topology
# Out:
# /home/jonasmensing/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# # Lattice Networks

# %%
# Parameter and Inti
N_x, N_y        = 5,3
electrode_pos   = [[0,0],[2,0],[0,2],[2,2]]
lattice_net     = topology.NanoparticleTopology()

# Build Network and attach Electrodes
lattice_net.lattice_network(N_x, N_y)
lattice_net.add_electrodes_to_lattice_net(electrode_pos)

# Extract Graph & Positions
G   = lattice_net.get_graph()
pos = lattice_net.get_positions()

print(lattice_net)
fig, ax = plt.subplots(dpi=150)
nx.draw_networkx(G=G, pos=pos, ax=ax)
# Out:
# Topology Class with 15 particles, 5 junctions.
# Network Topology:
# [[   1    1    5 -100 -100 -100]
#  [-100    0    2    6 -100 -100]
#  [   2    1    3    7 -100 -100]
#  [-100    2    4    8 -100 -100]
#  [-100    3    9 -100 -100 -100]
#  [-100    0    6   10 -100 -100]
#  [-100    1    5    7   11 -100]
#  [-100    2    6    8   12 -100]
#  [-100    3    7    9   13 -100]
#  [-100    4    8   14 -100 -100]
#  [   3    5   11 -100 -100 -100]
#  [-100    6   10   12 -100 -100]
#  [   4    7   11   13 -100 -100]
#  [-100    8   12   14 -100 -100]
#  [-100    9   13 -100 -100 -100]]

# %% [markdown]
# # Random Networks

# %%
# Parameter and Inti
N_particles     = 20
electrode_pos   = [[-1,-1],[-1,1],[1,-1],[1,1]]
rng_net         = topology.NanoparticleTopology()

# Build Network and attach Electrodes
rng_net.random_network(N_particles)
rng_net.add_electrodes_to_random_net(electrode_pos)

# Extract Graph & Positions
G   = rng_net.get_graph()
pos = rng_net.get_positions()

print(rng_net)
fig, ax = plt.subplots(dpi=150)
nx.draw_networkx(G=G, pos=pos, ax=ax)
# Out:
# Topology Class with 20 particles, 8 junctions.
# Network Topology:
# [[-100   18    3   12 -100 -100 -100 -100 -100]
#  [   3    5   17    7   13   19 -100 -100 -100]
#  [-100    4   12   18 -100 -100 -100 -100 -100]
#  [-100   18   11    0 -100 -100 -100 -100 -100]
#  [-100   12   18   14   17    2   10   19 -100]
#  [-100   19   12    1 -100 -100 -100 -100 -100]
#  [   4   15   14   16    9 -100 -100 -100 -100]
#  [-100   17   13    1 -100 -100 -100 -100 -100]
#  [-100   17   16   13 -100 -100 -100 -100 -100]
#  [-100   11   10   15    6 -100 -100 -100 -100]
#  [-100   18   15    9   11   14    4 -100 -100]
#  [   2    9   10    3   18 -100 -100 -100 -100]
#  [   1    4   19   18    5    0    2 -100 -100]
#  [-100   17    7    8    1 -100 -100 -100 -100]
#  [-100   16    6    4   15   10   17 -100 -100]
#  [-100    6   10   14    9 -100 -100 -100 -100]
#  [-100   14    6    8   17 -100 -100 -100 -100]
#  [-100    7   13    4    8    1   14   19   16]
#  [-100    4   10    0    3   12    2   11 -100]
#  [-100   12    5    4   17    1 -100 -100 -100]]

# %% [markdown]
# # Add a NP to the Output Electrode

# %%
# Parameter and Inti
N_x, N_y        = 5,3
electrode_pos   = [[0,0],[2,0],[0,2],[2,2]]
lattice_net     = topology.NanoparticleTopology()

# Build Network and attach Electrodes
lattice_net.lattice_network(N_x, N_y)
lattice_net.add_electrodes_to_lattice_net(electrode_pos)
lattice_net.add_np_to_output()

# Extract Graph & Positions
G   = lattice_net.get_graph()
pos = lattice_net.get_positions()

print(lattice_net)
fig, ax = plt.subplots(dpi=150)
nx.draw_networkx(G=G, pos=pos, ax=ax)
# Out:
# Topology Class with 16 particles, 5 junctions.
# Network Topology:
# [[   1    1    5 -100 -100 -100]
#  [-100    0    2    6 -100 -100]
#  [   2    1    3    7 -100 -100]
#  [-100    2    4    8 -100 -100]
#  [-100    3    9 -100 -100 -100]
#  [-100    0    6   10 -100 -100]
#  [-100    1    5    7   11 -100]
#  [-100    2    6    8   12 -100]
#  [-100    3    7    9   13 -100]
#  [-100    4    8   14 -100 -100]
#  [   3    5   11 -100 -100 -100]
#  [-100    6   10   12 -100 -100]
#  [-100    7   11   13   15 -100]
#  [-100    8   12   14 -100 -100]
#  [-100    9   13 -100 -100 -100]
#  [   4   12 -100 -100 -100 -100]]

# %%
# Parameter and Inti
N_particles     = 20
electrode_pos   = [[-1,-1],[-1,1],[1,-1],[1,1]]
rng_net         = topology.NanoparticleTopology()

# Build Network and attach Electrodes
rng_net.random_network(N_particles)
rng_net.add_electrodes_to_random_net(electrode_pos)
rng_net.add_np_to_output()

# Extract Graph & Positions
G   = rng_net.get_graph()
pos = rng_net.get_positions()

print(rng_net)
fig, ax = plt.subplots(dpi=150)
nx.draw_networkx(G=G, pos=pos, ax=ax)
# Out:
# Topology Class with 21 particles, 7 junctions.
# Network Topology:
# [[   2    1    7    9 -100 -100 -100 -100]
#  [-100   18    0    7   19 -100 -100 -100]
#  [-100   17   10   16   13    3   12 -100]
#  [-100   10   16   13   19    2 -100 -100]
#  [-100    9    6    8   14   11 -100 -100]
#  [-100   16    6   14   17 -100 -100 -100]
#  [-100    4   14    5    9   20 -100 -100]
#  [-100    0    9   15   18    1    8 -100]
#  [-100    9   15    4   11    7 -100 -100]
#  [-100    4    8    7    0    6 -100 -100]
#  [-100    3   12   18    2   19 -100 -100]
#  [-100   14    4    8   12   15 -100 -100]
#  [-100   10   15   18   14   17   11    2]
#  [-100    3   16    2 -100 -100 -100 -100]
#  [-100   11    6    4   12   17    5 -100]
#  [-100    8   12   18    7   11 -100 -100]
#  [   3    3    5    2   13   17 -100 -100]
#  [-100    2   12   14    5   16 -100 -100]
#  [-100   10    1   19   12   15    7 -100]
#  [   1    3   18   10    1 -100 -100 -100]
#  [   4    6 -100 -100 -100 -100 -100 -100]]
